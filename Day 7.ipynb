# %%
# outer function

def outer_fun(a,b) :
    square = a ** 2
    
    # inner function
    def addition(a,b) :
        return a+b
    
    # call inner function from outer function
    add = addition(a,b)
    # add 5 to the result
    return add + 5

result = outer_fun(3,10)
print (result)
# Out:
# 18

# %%
def detail(roll) :
    x=[23,45,67,50]
    if roll in x :
        print (f"roll number {roll} is present")
    else :
        print (f"roll number {roll} is absent")
roll = int(input("Enter roll number"))
detail(roll)
# Out:
# Enter roll number 45
# roll number 45 is present

# %%
def detail(roll) :
    y= [45,78,89,90]
    if roll in y :
        print(f" roll number {roll} is present")
    else :
        print(f" roll number {roll} is absent")
roll = int(input("Enter roll number"))
detail(roll)
# Out:
# Enter roll number 50
#  roll number 50 is absent

# %%
def func(x):
    if x%2==0:
        print (f"{x} is an even number")
    else :
        print(f"{x} is an odd number")
x = int(input("enter a number"))
func(x)
# Out:
# enter a number 5
# 5 is an odd number
