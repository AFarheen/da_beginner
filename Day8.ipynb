# %% [markdown]
# # IF statement (runs or skips code based on whether condition is true or false)

# %%
phn_balance = 3
bank_balance = 50
print(phn_balance, bank_balance)
if phn_balance <5 :
    phn_balance+= 10
    bank_balance-= 10
print(phn_balance,bank_balance)
# Out:
# 3 50
# 13 40

# %%
number = 21

if number%2==0:
        print ("number" + str(number) + " is an even number")
else :
        print("number" + str(number) + " is an odd number")
# Out:
# number21 is an odd number

# %% [markdown]
# # If elif and else

# %%
age = 2
free_upto_age = 4
child_upto_age = 18
senior_from_age = 65
concession_ticket = 1.25
adult_ticket = 2.50

if age<=free_upto_age :
    ticket_price = 0
elif age <= child_upto_age :
    ticket_price = concession_ticket
elif age>= senior_from_age :
    ticket_price = concession_ticket
else :
    ticket_price = adult_ticket

message = "Somebody who is {} yrs old will pay ${} to ride the bus. ".format(age,ticket_price)
print (message)
# Out:
# Somebody who is 2 yrs old will pay $0 to ride the bus.

# %%
phn_balance = 10
bank_balance = 20
loan_balance = 100

if phn_balance <10 :
    phn_balance += 10
    bank_balance -= 10
elif bank_balance <= 50 :
    loan_balance -= 10
print(phn_balance)
print(bank_balance)
print(loan_balance)
# Out:
# 10
# 20
# 90

# %% [markdown]
# #Write an if statement that lets a competitor know which of these prizes they won based on the number of points they scored, which is stored in the integer variable points.
#
# Points	Prize
# 1 - 50	 no prize
# 51 - 150	 wooden rabbit
# 151 - 180	wafer-thin mint
# 181 - 200	penguin

# %%
points = 100

if points <=50 :
    result = "Oh dear, no prize this time !"
elif points <=150 :
    result = "Congratulations ! you won a wooden rabbit"
elif points <=180 :
    result = "Congratulations ! you won a wafer-thin mint"
else:
    result = " Congratulations ! you won a Penguin"
print (result)
# Out:
# Congratulations ! you won a wooden rabbit

# %%
points = 170

if points <=50 :
    result = "Oh dear, no prize this time !"
elif points <=150 :
    result = "Congratulations ! you won a wooden rabbit"
elif points%2 ==0 :
    result = "Congratulations ! you won a wafer-thin mint"
else:
    result = " Congratulations ! you won a Penguin"
print (result)
# Out:
# Congratulations ! you won a wafer-thin mint

# %% [markdown]
# answer = 35
# guess = 30 (change and try with diff values)
#
# guess < answer
# result = your guess is too low
# guess > answer
# result = you guess is too high
# guess = answr
# result = result matched
# print(result)

# %%
answer = 35
guess = 35

if guess < answer :
    result = " Your guess is too low"
elif guess > answer :
    result = "your guess is too high"
elif guess == answer :
    result = " Result Matched"
    
print(result)
# Out:
#  Result Matched

# %%
answer = 35
guess = int(input("Enter a number"))
if guess < answer :
    result = " Your guess is too low"
elif guess > answer :
    result = "your guess is too high"
elif guess == answer :
    result = " Result Matched"
    
print(result)
# Out:
# Enter a number 50
# your guess is too high
